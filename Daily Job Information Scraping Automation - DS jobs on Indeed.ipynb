# %% [markdown]
# # Web Scraping - DS jobs in Canada

# %% [markdown]
# This code is created to automate the process of daily personal job search - DS job scraping.
#
# Requirements are:
#     1. from indeed in cities of Toronto, Montreal, Calgary and Vancouver, Canada;
#     2  Full time position only;
#     3. title as "data scientist / data analyst / data engineer";
#     4. information scraped include: application deadline, application link, job title, company name, whether require python skills;
#     5. sort by application deadline;

# %%
# define interested city list
city_set = ['Calgary','Montreal','Toronto', 'Vancouver']

# define search time range: job posted within last # of days
n_days = 5

# %%
# import all required libraries
import pandas as pd
import time
import datetime

import requests
import numpy as np

import bs4
from bs4 import BeautifulSoup

from urllib.parse import urljoin
import lxml.html

# %%
def evaluate_job(job_url):
    try:
        job_html = requests.request('GET', job_url, timeout = 25)
    except:
        return 0
    
    job_soup = bs4.BeautifulSoup(job_html.content, 'lxml')
    soup_body = job_soup('body')[0]
    
    if soup_body.text.count('PYTHON') +soup_body.text.count('Python') + soup_body.text.count('python') > 0:
        python_count = 'Y'
    else:
        python_count = 'N'

    return python_count

# %%
start = time.time()-n_days*86400

linklist = list()
python_input = list()
deadline_input = list()
job_title = []
company_name = []
location = []

def getlinkindeed (joblist,df): 
    base_link = 'https://www.indeed.com/'
    start = time.time()
    for city in city_set:
        page = requests.get('https://ca.indeed.com/jobs?q='+str(joblist)+'&l=' + str(city) + '&amp;jt=fulltime&amp;sort=date'+'&start=' + str(start))
        soup = BeautifulSoup(page.text, 'lxml')#, from_encoding='utf-8')
        for div in soup.find_all(name="div", attrs={"class":"row"}):
            for a in div.find_all(name="a", attrs={'data-tn-element':'jobTitle'}):
                finallinktext = base_link+a['href']
                linklist.append(base_link+a['href'])
                    
                python_input.append(evaluate_job(finallinktext))
                    
                try:
                    job_title.append(a['title'])
                except:
                    job_title.append('NAN')
                    

            company = div.find_all(name="span", attrs={"class":"company"})
                
            if len(company) > 0:
                for b in company:
                    company_name.append(b.text.strip())
                    break
                else:
                    sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                    for span in sec_try:
                        company_name.append(span.text)

            location.append(city)
    
    df['job_title'] = job_title
    df['company_name'] = company_name
    df['location'] = location
    df['job_link'] = linklist
    df['Require Python?'] = python_input
    
    return df.drop_duplicates(['job_title','company_name'],keep= 'last')

# %%
DS_job = getlinkindeed ('data+scientist',pd.DataFrame())
DS_job['Type'] = 'Data Scientist'

# %%
DA_job = getlinkindeed ('data+analyst',pd.DataFrame())
DA_job['Type'] = 'Data Analyst'

# %%
DE_job = getlinkindeed ('data+engineer',pd.DataFrame())
DE_job['Type'] = 'Data Engineer'

# %%
frames = [DS_job, DA_job, DE_job]
Final_List = pd.concat(frames).reset_index(drop=True)
Final_List
# Out:
#                                              job_title  \
# 0                         Data Scientist - Calgary, AB
# 1                           Water Quality Data Analyst
# 2           Data Scientist,Research Computing Services
# 3                                  Junior Data Analyst
# 4                     Data Scientist +Python Developer
# 5                                       Soil Scientist
# 6    Senior Research Scientist (Research Scientist,...
# 7                                       DATA SCIENTIST
# 8                       Environmental Scientist - LM&R
# 9                              Water Quality Scientist
# 10                          Data Scientist in big data
# 11                             Data Analytics Engineer
# 12              Associate Scientist - DMPK Bioanalysis
# 13              Intermediate Computer Vision Scientist
# 14                                      Data Scientist
# 15                                      Data Scientist
# 16   AI Data Scientist - Biomedical and Image Proce...
# 17                                      Data Scientist
# 18                                      Data Scientist
# 19                               Data Scientist Intern
# 20               Développeur / Data Scientist - Python
# 21                                   AI Data Scientist
# 22                  Data Scientist – Wealth management
# 23                               Data Scientist Intern
# 24                               Formulation Scientist
# 25                                      Data Scientist
# 26                  Data Scientist, RBC Amplify - 2019
# 27                                      Data Scientist
# 28                            Data Scientist (Manager)
# 29                        Scientist, Zero Gravity Labs
# ..                                                 ...
# 316                                    DevOps Engineer
# 317                                 Big Data Developer
# 318                                      Data Engineer
# 319                                      Data Engineer
# 320                                  Sr. Data Engineer
# 321                            Molecular Data Engineer
# 322                                      Data Engineer
# 323                   Data Engineer (Alternative Data)
# 324                    Women in Data & Analytics event
# 325                  CATO - Data Engineer (Consultant)
# 326                        Data Engineer, Self Driving
# 327                                     Data Scientist
# 328                                  Software Engineer
# 329                                      Data Engineer
# 330                          Vision Algorithm Engineer
# 331  Intemediate to Senior Civil/Environmental Engi...
# 332                                      Data Engineer
# 333                         Embedded Software Engineer
# 334           Data Engineer (Hadoop), 4-month contract
# 335                                      Data Engineer
# 336                                      Data Engineer
# 337                                   Project Engineer
# 338                                     Data Scientist
# 339                             Data Engineer - NuData
# 340                                   NEW GRADS (2018)
# 341            Junior Data Engineer BurnabyHead Office
# 342                                      Data Engineer
# 343                                      Data Engineer
# 344                                  Platform Engineer
# 345                                  Solution Engineer
#
#                                company_name   location  \
# 0                           RS Energy Group    Calgary
# 1                     Government of Alberta    Calgary
# 2                     University of Calgary    Calgary
# 3                         AGAT Laboratories    Calgary
# 4                           MVP Talent Corp    Calgary
# 5                             WorleyParsons    Calgary
# 6                            NOVA Chemicals    Calgary
# 7                                     BOWEN    Calgary
# 8                             WorleyParsons    Calgary
# 9                     Matrix Solutions Inc.    Calgary
# 10                                   Intact   Montreal
# 11                                   Intact   Montreal
# 12                       Paraza Pharma Inc.   Montreal
# 13                          Mirametrix Inc.   Montreal
# 14                           Dataperformers   Montreal
# 15                                NestReady   Montreal
# 16                             Corstem Inc.   Montreal
# 17            TMC - People Drive Technology   Montreal
# 18                                   B.Yond   Montreal
# 19                     Camfil Power Systems   Montreal
# 20      Resolution -- Compliance Consulting   Montreal
# 21                                      PwC   Montreal
# 22                  National Bank of Canada   Montreal
# 23                     Seedbox Technologies   Montreal
# 24              TetraGenx Animal Health ULC   Montreal
# 25                                 MindGeek   Montreal
# 26                                      RBC    Toronto
# 27                                    Xylem    Toronto
# 28                               LoyaltyOne    Toronto
# 29                               LoyaltyOne    Toronto
# ..                                      ...        ...
# 316                 Digital Media Solutions    Toronto
# 317                              LoyaltyOne    Toronto
# 318                                EQ Works    Toronto
# 319                                Manulife    Toronto
# 320             Infotek Consulting Services    Toronto
# 321  Centre for Addiction and Mental Health    Toronto
# 322                               PagerDuty    Toronto
# 323                              Quandl Inc    Toronto
# 324                                 TD Bank    Toronto
# 325                                   CAPCO    Toronto
# 326                                    Uber    Toronto
# 327                                   Aimia    Toronto
# 328                               Mavencare    Toronto
# 329                                 Precima    Toronto
# 330                        LMI Technologies  Vancouver
# 331          MEK Earth & Environmental Inc.  Vancouver
# 332                  Annex Consulting Group  Vancouver
# 333                        LMI Technologies  Vancouver
# 334                              Ecotagious  Vancouver
# 335                                    ICBC  Vancouver
# 336                              UrbanLogiq  Vancouver
# 337                    Government of Canada  Vancouver
# 338                     lululemon athletica  Vancouver
# 339                              MasterCard  Vancouver
# 340                                Fortinet  Vancouver
# 341                         Best Buy Canada  Vancouver
# 342                             Hyperwallet  Vancouver
# 343                Hyperwallet Systems Inc.  Vancouver
# 344                             Cargo Chief  Vancouver
# 345                             LoginRadius  Vancouver
#
#                                               job_link Require Python?  \
# 0    https://www.indeed.com//rc/clk?jk=ac48b39d18dc...               Y
# 1    https://www.indeed.com//rc/clk?jk=1a1867ce4cbc...               N
# 2    https://www.indeed.com//rc/clk?jk=3bc37336d84c...               Y
# 3    https://www.indeed.com//company/AGAT-Laborator...               N
# 4    https://www.indeed.com//company/MVP-Talent-Cor...               Y
# 5    https://www.indeed.com//rc/clk?jk=e4bcfa3d3623...               N
# 6    https://www.indeed.com//rc/clk?jk=b672eb513914...               N
# 7    https://www.indeed.com//rc/clk?jk=8feb3a462af5...               N
# 8    https://www.indeed.com//rc/clk?jk=7e6b1c8bb675...               N
# 9    https://www.indeed.com//rc/clk?jk=446857233d64...               N
# 10   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 11   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 12   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 13   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 14   https://www.indeed.com//company/Dataperformers...               Y
# 15   https://www.indeed.com//rc/clk?jk=114e9a483bed...               Y
# 16   https://www.indeed.com//company/Corstem/jobs/A...               Y
# 17   https://www.indeed.com//company/TMC---People-D...               Y
# 18   https://www.indeed.com//rc/clk?jk=d8ed30befe6c...               Y
# 19   https://www.indeed.com//company/Camfil-Farr-Po...               Y
# 20   https://www.indeed.com//rc/clk?jk=f986a251db57...               Y
# 21   https://www.indeed.com//rc/clk?jk=b90280ee005d...               Y
# 22   https://www.indeed.com//rc/clk?jk=a8c542366602...               Y
# 23   https://www.indeed.com//rc/clk?jk=12be64533840...               Y
# 24   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 25   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 26   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 27   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 28   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 29   https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# ..                                                 ...             ...
# 316  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 317  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 318  https://www.indeed.com//rc/clk?jk=ef9fe866b1ba...               N
# 319  https://www.indeed.com//rc/clk?jk=9dcb326ca2fe...               Y
# 320  https://www.indeed.com//company/Infotek-Consul...               Y
# 321  https://www.indeed.com//rc/clk?jk=ad136059d161...               N
# 322  https://www.indeed.com//rc/clk?jk=d502e279211f...               Y
# 323  https://www.indeed.com//rc/clk?jk=4b6c8a545f5a...               Y
# 324  https://www.indeed.com//rc/clk?jk=106fb851b319...               N
# 325  https://www.indeed.com//rc/clk?jk=dd92041388ba...               Y
# 326  https://www.indeed.com//rc/clk?jk=26461d69bb72...               Y
# 327  https://www.indeed.com//rc/clk?jk=ced59f16092f...               Y
# 328  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 329  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 330  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 331  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 332  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 333  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
# 334  https://www.indeed.com//company/Ecotagious/job...               N
# 335  https://www.indeed.com//rc/clk?jk=31656bfedde2...               N
# 336  https://www.indeed.com//rc/clk?jk=47155087c40d...               Y
# 337  https://www.indeed.com//rc/clk?jk=c7387a56fd5f...               Y
# 338  https://www.indeed.com//rc/clk?jk=effb4bfec420...               Y
# 339  https://www.indeed.com//rc/clk?jk=90b9fb641147...               Y
# 340  https://www.indeed.com//rc/clk?jk=aef7e873f3d0...               N
# 341  https://www.indeed.com//rc/clk?jk=7df9793600ad...               Y
# 342  https://www.indeed.com//rc/clk?jk=098ccfcf4fe7...               N
# 343  https://www.indeed.com//rc/clk?jk=02ad0a74dad9...               N
# 344  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               Y
# 345  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...               N
#
#                Type
# 0    Data Scientist
# 1    Data Scientist
# 2    Data Scientist
# 3    Data Scientist
# 4    Data Scientist
# 5    Data Scientist
# 6    Data Scientist
# 7    Data Scientist
# 8    Data Scientist
# 9    Data Scientist
# 10   Data Scientist
# 11   Data Scientist
# 12   Data Scientist
# 13   Data Scientist
# 14   Data Scientist
# 15   Data Scientist
# 16   Data Scientist
# 17   Data Scientist
# 18   Data Scientist
# 19   Data Scientist
# 20   Data Scientist
# 21   Data Scientist
# 22   Data Scientist
# 23   Data Scientist
# 24   Data Scientist
# 25   Data Scientist
# 26   Data Scientist
# 27   Data Scientist
# 28   Data Scientist
# 29   Data Scientist
# ..              ...
# 316   Data Engineer
# 317   Data Engineer
# 318   Data Engineer
# 319   Data Engineer
# 320   Data Engineer
# 321   Data Engineer
# 322   Data Engineer
# 323   Data Engineer
# 324   Data Engineer
# 325   Data Engineer
# 326   Data Engineer
# 327   Data Engineer
# 328   Data Engineer
# 329   Data Engineer
# 330   Data Engineer
# 331   Data Engineer
# 332   Data Engineer
# 333   Data Engineer
# 334   Data Engineer
# 335   Data Engineer
# 336   Data Engineer
# 337   Data Engineer
# 338   Data Engineer
# 339   Data Engineer
# 340   Data Engineer
# 341   Data Engineer
# 342   Data Engineer
# 343   Data Engineer
# 344   Data Engineer
# 345   Data Engineer
#
# [346 rows x 6 columns]

# %%
# save to csv with labels
Final_List.to_csv('Job_List_CreatedAt' +str(datetime.datetime.now().strftime("%Y-%m-%d"))+'_Last'+str(n_days)+'Days.csv')
